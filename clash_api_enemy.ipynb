# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import json
from pandas import json_normalize
import re

# load_dotenv

# token = os.getenv("API_TOKEN")

# headers = {
#     'Authorization': f'Bearer {token}',
#     'Content-Type': 'application.json'
# }
# response = requests.get('https://api.clashofclans.com/v1/clans/%232GLLPQYLL/currentwar', headers=headers)
# response = response.json()

# %%
with open('war1.json', "r") as json_data:
    response = json.load(json_data)

# %%
data = json_normalize(response, record_path=['opponent', 'members'])
data
# Out:
#            tag            name  townhallLevel  mapPosition  \
# 0   #GL2GC2PQ8           nacho             13            8
# 1   #LJVUCC9RC      KIKI_Games             10           15
# 2    #P2JGVYRP             vak             11           10
# 3   #2JGVRGVRV      Krloz Fire             15            5
# 4   #GLPJPGPQ2            ivan             11           14
# 5   #9VC2P0CQR          TAYSON             13            6
# 6   #GL2YCLVCC        la mafia             11           11
# 7   #82CY8YUUJ         the jma             15            4
# 8   #GY9CPCLC8           saulo             11           13
# 9   #LUQQJCCQC           TELLO             15            3
# 10  #LV2990URP  Xx SANTYAGO xX             11            9
# 11  #LCGR0Y2RC          josias             12            7
# 12  #Y9CJRGJYC    kenny carlos             16            2
# 13  #9R8CYRJP9          ismael             16            1
# 14  #G8JQCRRCR         R.H.L.M             11           12
#
#                                               attacks  opponentAttacks  \
# 0   [{'attackerTag': '#GL2GC2PQ8', 'defenderTag': ...                2
# 1   [{'attackerTag': '#LJVUCC9RC', 'defenderTag': ...                1
# 2   [{'attackerTag': '#P2JGVYRP', 'defenderTag': '...                1
# 3   [{'attackerTag': '#2JGVRGVRV', 'defenderTag': ...                0
# 4                                                 NaN                2
# 5   [{'attackerTag': '#9VC2P0CQR', 'defenderTag': ...                1
# 6   [{'attackerTag': '#GL2YCLVCC', 'defenderTag': ...                2
# 7   [{'attackerTag': '#82CY8YUUJ', 'defenderTag': ...                1
# 8   [{'attackerTag': '#GY9CPCLC8', 'defenderTag': ...                1
# 9                                                 NaN                0
# 10                                                NaN                1
# 11                                                NaN                2
# 12  [{'attackerTag': '#Y9CJRGJYC', 'defenderTag': ...                1
# 13  [{'attackerTag': '#9R8CYRJP9', 'defenderTag': ...                1
# 14                                                NaN                1
#
#    bestOpponentAttack.attackerTag bestOpponentAttack.defenderTag  \
# 0                      #GYQ09LYRR                     #GL2GC2PQ8
# 1                      #GPC0JCLPG                     #LJVUCC9RC
# 2                       #UGRL8LV8                      #P2JGVYRP
# 3                             NaN                            NaN
# 4                      #GPRURPLRG                     #GLPJPGPQ2
# 5                       #9PRCGP9Y                     #9VC2P0CQR
# 6                      #GGV0JPQ2C                     #GL2YCLVCC
# 7                       #9PRCGP9Y                     #82CY8YUUJ
# 8                      #GPRURPLRG                     #GY9CPCLC8
# 9                             NaN                            NaN
# 10                     #GYQ09LYRR                     #LV2990URP
# 11                      #UGRL8LV8                     #LCGR0Y2RC
# 12                      #9GGVU8C8                     #Y9CJRGJYC
# 13                      #9GGVU8C8                     #9R8CYRJP9
# 14                     #G222UU009                     #G8JQCRRCR
#
#     bestOpponentAttack.stars  bestOpponentAttack.destructionPercentage  \
# 0                        1.0                                      88.0
# 1                        3.0                                     100.0
# 2                        3.0                                     100.0
# 3                        NaN                                       NaN
# 4                        3.0                                     100.0
# 5                        3.0                                     100.0
# 6                        1.0                                      47.0
# 7                        3.0                                     100.0
# 8                        3.0                                     100.0
# 9                        NaN                                       NaN
# 10                       3.0                                     100.0
# 11                       3.0                                     100.0
# 12                       2.0                                      97.0
# 13                       1.0                                      77.0
# 14                       3.0                                     100.0
#
#     bestOpponentAttack.order  bestOpponentAttack.duration
# 0                       13.0                         87.0
# 1                        6.0                        114.0
# 2                       28.0                         75.0
# 3                        NaN                          NaN
# 4                       29.0                        132.0
# 5                       33.0                        110.0
# 6                       25.0                         93.0
# 7                       31.0                        112.0
# 8                        2.0                        102.0
# 9                        NaN                          NaN
# 10                      12.0                        124.0
# 11                      30.0                         96.0
# 12                      24.0                        180.0
# 13                      21.0                        109.0
# 14                      20.0                        118.0

# %%
members_df = json_normalize(response, record_path=['opponent', 'members'], meta=[])
total_members_df = members_df.copy()

# %%
attacks_df = json_normalize(
    members_df.to_dict(orient='records'),  # Convert DataFrame to dicts
    record_path='attacks',
    meta=['name'],
    meta_prefix='member_'
)
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0   #GL2GC2PQ8   #8Q8UQL8Y      3                    100      8       150
# 1   #GL2GC2PQ8  #P22YPY90V      2                     93      9       180
# 2   #LJVUCC9RC  #GGV0JPQ2C      2                     97      1       180
# 3    #P2JGVYRP  #LPG2LYYGJ      2                     87     23       180
# 4   #2JGVRGVRV   #UGRL8LV8      2                     93     14       173
# 5   #2JGVRGVRV   #8CRG2JR9      3                    100     15       127
# 6   #9VC2P0CQR  #GYQ09LYRR      3                    100     16        91
# 7   #9VC2P0CQR  #L99GG88LG      3                    100     17       130
# 8   #GL2YCLVCC  #GPRURPLRG      3                    100     27       139
# 9   #82CY8YUUJ   #UGRL8LV8      2                     83     26       117
# 10  #GY9CPCLC8  #GPC0JCLPG      3                    100     18       124
# 11  #GY9CPCLC8  #G222UU009      3                    100     19       144
# 12  #Y9CJRGJYC   #9PRCGP9Y      2                     99      4       180
# 13  #Y9CJRGJYC    #899PLPG      3                    100      5       122
# 14  #9R8CYRJP9   #2RR2PVRG      3                    100      3       145
# 15  #9R8CYRJP9   #9GGVU8C8      2                     73     22       147
#
#      member_name
# 0          nacho
# 1          nacho
# 2     KIKI_Games
# 3            vak
# 4     Krloz Fire
# 5     Krloz Fire
# 6         TAYSON
# 7         TAYSON
# 8       la mafia
# 9        the jma
# 10         saulo
# 11         saulo
# 12  kenny carlos
# 13  kenny carlos
# 14        ismael
# 15        ismael

# %%
attacks_df['attack_num'] = attacks_df.groupby('member_name').cumcount() + 1
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0   #GL2GC2PQ8   #8Q8UQL8Y      3                    100      8       150
# 1   #GL2GC2PQ8  #P22YPY90V      2                     93      9       180
# 2   #LJVUCC9RC  #GGV0JPQ2C      2                     97      1       180
# 3    #P2JGVYRP  #LPG2LYYGJ      2                     87     23       180
# 4   #2JGVRGVRV   #UGRL8LV8      2                     93     14       173
# 5   #2JGVRGVRV   #8CRG2JR9      3                    100     15       127
# 6   #9VC2P0CQR  #GYQ09LYRR      3                    100     16        91
# 7   #9VC2P0CQR  #L99GG88LG      3                    100     17       130
# 8   #GL2YCLVCC  #GPRURPLRG      3                    100     27       139
# 9   #82CY8YUUJ   #UGRL8LV8      2                     83     26       117
# 10  #GY9CPCLC8  #GPC0JCLPG      3                    100     18       124
# 11  #GY9CPCLC8  #G222UU009      3                    100     19       144
# 12  #Y9CJRGJYC   #9PRCGP9Y      2                     99      4       180
# 13  #Y9CJRGJYC    #899PLPG      3                    100      5       122
# 14  #9R8CYRJP9   #2RR2PVRG      3                    100      3       145
# 15  #9R8CYRJP9   #9GGVU8C8      2                     73     22       147
#
#      member_name  attack_num
# 0          nacho           1
# 1          nacho           2
# 2     KIKI_Games           1
# 3            vak           1
# 4     Krloz Fire           1
# 5     Krloz Fire           2
# 6         TAYSON           1
# 7         TAYSON           2
# 8       la mafia           1
# 9        the jma           1
# 10         saulo           1
# 11         saulo           2
# 12  kenny carlos           1
# 13  kenny carlos           2
# 14        ismael           1
# 15        ismael           2

# %%
attacks_df['total_attacks'] = attacks_df.groupby('member_name')['attack_num'].transform('max')
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0   #GL2GC2PQ8   #8Q8UQL8Y      3                    100      8       150
# 1   #GL2GC2PQ8  #P22YPY90V      2                     93      9       180
# 2   #LJVUCC9RC  #GGV0JPQ2C      2                     97      1       180
# 3    #P2JGVYRP  #LPG2LYYGJ      2                     87     23       180
# 4   #2JGVRGVRV   #UGRL8LV8      2                     93     14       173
# 5   #2JGVRGVRV   #8CRG2JR9      3                    100     15       127
# 6   #9VC2P0CQR  #GYQ09LYRR      3                    100     16        91
# 7   #9VC2P0CQR  #L99GG88LG      3                    100     17       130
# 8   #GL2YCLVCC  #GPRURPLRG      3                    100     27       139
# 9   #82CY8YUUJ   #UGRL8LV8      2                     83     26       117
# 10  #GY9CPCLC8  #GPC0JCLPG      3                    100     18       124
# 11  #GY9CPCLC8  #G222UU009      3                    100     19       144
# 12  #Y9CJRGJYC   #9PRCGP9Y      2                     99      4       180
# 13  #Y9CJRGJYC    #899PLPG      3                    100      5       122
# 14  #9R8CYRJP9   #2RR2PVRG      3                    100      3       145
# 15  #9R8CYRJP9   #9GGVU8C8      2                     73     22       147
#
#      member_name  attack_num  total_attacks
# 0          nacho           1              2
# 1          nacho           2              2
# 2     KIKI_Games           1              1
# 3            vak           1              1
# 4     Krloz Fire           1              2
# 5     Krloz Fire           2              2
# 6         TAYSON           1              2
# 7         TAYSON           2              2
# 8       la mafia           1              1
# 9        the jma           1              1
# 10         saulo           1              2
# 11         saulo           2              2
# 12  kenny carlos           1              2
# 13  kenny carlos           2              2
# 14        ismael           1              2
# 15        ismael           2              2

# %%
total_attacks_df = attacks_df[['member_name', 'total_attacks']].drop_duplicates().set_index('member_name')
total_attacks_df
# Out:
#               total_attacks
# member_name
# nacho                     2
# KIKI_Games                1
# vak                       1
# Krloz Fire                2
# TAYSON                    2
# la mafia                  1
# the jma                   1
# saulo                     2
# kenny carlos              2
# ismael                    2

# %%
pivot_df = attacks_df.pivot_table(
    index=['member_name'], 
    columns='attack_num', 
    values=['attackerTag', 'defenderTag', 'stars', 'destructionPercentage', 'order', 'duration'], 
    aggfunc='first'
)
pivot_df
# Out:
#              attackerTag             defenderTag              \
# attack_num             1           2           1           2
# member_name
# KIKI_Games    #LJVUCC9RC         NaN  #GGV0JPQ2C         NaN
# Krloz Fire    #2JGVRGVRV  #2JGVRGVRV   #UGRL8LV8   #8CRG2JR9
# TAYSON        #9VC2P0CQR  #9VC2P0CQR  #GYQ09LYRR  #L99GG88LG
# ismael        #9R8CYRJP9  #9R8CYRJP9   #2RR2PVRG   #9GGVU8C8
# kenny carlos  #Y9CJRGJYC  #Y9CJRGJYC   #9PRCGP9Y    #899PLPG
# la mafia      #GL2YCLVCC         NaN  #GPRURPLRG         NaN
# nacho         #GL2GC2PQ8  #GL2GC2PQ8   #8Q8UQL8Y  #P22YPY90V
# saulo         #GY9CPCLC8  #GY9CPCLC8  #GPC0JCLPG  #G222UU009
# the jma       #82CY8YUUJ         NaN   #UGRL8LV8         NaN
# vak            #P2JGVYRP         NaN  #LPG2LYYGJ         NaN
#
#              destructionPercentage        duration        order       stars  \
# attack_num                       1      2        1      2     1     2     1
# member_name
# KIKI_Games                    97.0    NaN    180.0    NaN   1.0   NaN   2.0
# Krloz Fire                    93.0  100.0    173.0  127.0  14.0  15.0   2.0
# TAYSON                       100.0  100.0     91.0  130.0  16.0  17.0   3.0
# ismael                       100.0   73.0    145.0  147.0   3.0  22.0   3.0
# kenny carlos                  99.0  100.0    180.0  122.0   4.0   5.0   2.0
# la mafia                     100.0    NaN    139.0    NaN  27.0   NaN   3.0
# nacho                        100.0   93.0    150.0  180.0   8.0   9.0   3.0
# saulo                        100.0  100.0    124.0  144.0  18.0  19.0   3.0
# the jma                       83.0    NaN    117.0    NaN  26.0   NaN   2.0
# vak                           87.0    NaN    180.0    NaN  23.0   NaN   2.0
#
#
# attack_num      2
# member_name
# KIKI_Games    NaN
# Krloz Fire    3.0
# TAYSON        3.0
# ismael        2.0
# kenny carlos  3.0
# la mafia      NaN
# nacho         2.0
# saulo         3.0
# the jma       NaN
# vak           NaN

# %%
pivot_df.columns = [f"{col[0]}_{col[1]}" for col in pivot_df.columns]

# %%
def extract_text_and_number(column_name):
    match = re.match(r'(.+?)_(\d+)', column_name)
    return (int(match.group(2)), match.group(1)) if match else (float('inf'), column_name)

# %%
sorted_columns = sorted(pivot_df.columns, key=lambda x: extract_text_and_number(x))
sorted_columns
# Out:
# ['attackerTag_1',
#  'defenderTag_1',
#  'destructionPercentage_1',
#  'duration_1',
#  'order_1',
#  'stars_1',
#  'attackerTag_2',
#  'defenderTag_2',
#  'destructionPercentage_2',
#  'duration_2',
#  'order_2',
#  'stars_2']

# %%
pivot_df = pivot_df[sorted_columns]

# %%
final_df = pivot_df.join(total_attacks_df)
final_df
# Out:
#              attackerTag_1 defenderTag_1  destructionPercentage_1  duration_1  \
# member_name
# KIKI_Games      #LJVUCC9RC    #GGV0JPQ2C                     97.0       180.0
# Krloz Fire      #2JGVRGVRV     #UGRL8LV8                     93.0       173.0
# TAYSON          #9VC2P0CQR    #GYQ09LYRR                    100.0        91.0
# ismael          #9R8CYRJP9     #2RR2PVRG                    100.0       145.0
# kenny carlos    #Y9CJRGJYC     #9PRCGP9Y                     99.0       180.0
# la mafia        #GL2YCLVCC    #GPRURPLRG                    100.0       139.0
# nacho           #GL2GC2PQ8     #8Q8UQL8Y                    100.0       150.0
# saulo           #GY9CPCLC8    #GPC0JCLPG                    100.0       124.0
# the jma         #82CY8YUUJ     #UGRL8LV8                     83.0       117.0
# vak              #P2JGVYRP    #LPG2LYYGJ                     87.0       180.0
#
#               order_1  stars_1 attackerTag_2 defenderTag_2  \
# member_name
# KIKI_Games        1.0      2.0           NaN           NaN
# Krloz Fire       14.0      2.0    #2JGVRGVRV     #8CRG2JR9
# TAYSON           16.0      3.0    #9VC2P0CQR    #L99GG88LG
# ismael            3.0      3.0    #9R8CYRJP9     #9GGVU8C8
# kenny carlos      4.0      2.0    #Y9CJRGJYC      #899PLPG
# la mafia         27.0      3.0           NaN           NaN
# nacho             8.0      3.0    #GL2GC2PQ8    #P22YPY90V
# saulo            18.0      3.0    #GY9CPCLC8    #G222UU009
# the jma          26.0      2.0           NaN           NaN
# vak              23.0      2.0           NaN           NaN
#
#               destructionPercentage_2  duration_2  order_2  stars_2  \
# member_name
# KIKI_Games                        NaN         NaN      NaN      NaN
# Krloz Fire                      100.0       127.0     15.0      3.0
# TAYSON                          100.0       130.0     17.0      3.0
# ismael                           73.0       147.0     22.0      2.0
# kenny carlos                    100.0       122.0      5.0      3.0
# la mafia                          NaN         NaN      NaN      NaN
# nacho                            93.0       180.0      9.0      2.0
# saulo                           100.0       144.0     19.0      3.0
# the jma                           NaN         NaN      NaN      NaN
# vak                               NaN         NaN      NaN      NaN
#
#               total_attacks
# member_name
# KIKI_Games                1
# Krloz Fire                2
# TAYSON                    2
# ismael                    2
# kenny carlos              2
# la mafia                  1
# nacho                     2
# saulo                     2
# the jma                   1
# vak                       1

# %%
new_name_df = final_df
new_name_df['Avg %'] = new_name_df[['destructionPercentage_1', 'destructionPercentage_2']].mean(axis=1)
new_name_df['Total Stars'] = new_name_df[["stars_1", "stars_2"]].sum(axis=1)

# %%
new_order = ['total_attacks', 'Avg %', 'destructionPercentage_1', 'destructionPercentage_2', 
             'stars_1', 'stars_2', 'Total Stars']
new_name_df = new_name_df[new_order]
final_name_df = new_name_df.rename(columns={'destructionPercentage_1' : 'Attack 1 %', 'destructionPercentage_2' : 'Attack 2 %', 
                                            'stars_1' : 'Attack 1 Stars', 'stars_2' : 'Attack 2 Stars', 'total_attacks' : 'Total Attacks'})
final_name_df
# Out:
#               Total Attacks  Avg %  Attack 1 %  Attack 2 %  Attack 1 Stars  \
# member_name
# KIKI_Games                1   97.0        97.0         NaN             2.0
# Krloz Fire                2   96.5        93.0       100.0             2.0
# TAYSON                    2  100.0       100.0       100.0             3.0
# ismael                    2   86.5       100.0        73.0             3.0
# kenny carlos              2   99.5        99.0       100.0             2.0
# la mafia                  1  100.0       100.0         NaN             3.0
# nacho                     2   96.5       100.0        93.0             3.0
# saulo                     2  100.0       100.0       100.0             3.0
# the jma                   1   83.0        83.0         NaN             2.0
# vak                       1   87.0        87.0         NaN             2.0
#
#               Attack 2 Stars  Total Stars
# member_name
# KIKI_Games               NaN          2.0
# Krloz Fire               3.0          5.0
# TAYSON                   3.0          6.0
# ismael                   2.0          5.0
# kenny carlos             3.0          5.0
# la mafia                 NaN          3.0
# nacho                    2.0          5.0
# saulo                    3.0          6.0
# the jma                  NaN          2.0
# vak                      NaN          2.0

# %%
try:
    total_members_df = total_members_df.set_index('name')
except KeyError:
    pass

# %%
combined_df = final_name_df.reindex(total_members_df.index)
combined_df.fillna(0, inplace=True)
combined_df.sort_values(["Total Attacks", 'Total Stars', 'Avg %'], ascending=False, inplace=True)

# %%
def colors(row):
    if row['Total Attacks'] == 2.0:
        color = "rgb(0,255,0)"
    elif row['Total Attacks'] == 1.0:
        color = "yellow"
    else:
        color = "red"
    return [f'color: {color}'] * len(row)

# %%
styled_df = combined_df.style.apply(colors, axis=1).format('{:.1f}')
styled_df
# Out:
# <style type="text/css">
# #T_68210_row0_col0, #T_68210_row0_col1, #T_68210_row0_col2, #T_68210_row0_col3, #T_68210_row0_col4, #T_68210_row0_col5, #T_68210_row0_col6, #T_68210_row1_col0, #T_68210_row1_col1, #T_68210_row1_col2, #T_68210_row1_col3, #T_68210_row1_col4, #T_68210_row1_col5, #T_68210_row1_col6, #T_68210_row2_col0, #T_68210_row2_col1, #T_68210_row2_col2, #T_68210_row2_col3, #T_68210_row2_col4, #T_68210_row2_col5, #T_68210_row2_col6, #T_68210_row3_col0, #T_68210_row3_col1, #T_68210_row3_col2, #T_68210_row3_col3, #T_68210_row3_col4, #T_68210_row3_col5, #T_68210_row3_col6, #T_68210_row4_col0, #T_68210_row4_col1, #T_68210_row4_col2, #T_68210_row4_col3, #T_68210_row4_col4, #T_68210_row4_col5, #T_68210_row4_col6, #T_68210_row5_col0, #T_68210_row5_col1, #T_68210_row5_col2, #T_68210_row5_col3, #T_68210_row5_col4, #T_68210_row5_col5, #T_68210_row5_col6 {
#   color: rgb(0,255,0);
# }
# #T_68210_row6_col0, #T_68210_row6_col1, #T_68210_row6_col2, #T_68210_row6_col3, #T_68210_row6_col4, #T_68210_row6_col5, #T_68210_row6_col6, #T_68210_row7_col0, #T_68210_row7_col1, #T_68210_row7_col2, #T_68210_row7_col3, #T_68210_row7_col4, #T_68210_row7_col5, #T_68210_row7_col6, #T_68210_row8_col0, #T_68210_row8_col1, #T_68210_row8_col2, #T_68210_row8_col3, #T_68210_row8_col4, #T_68210_row8_col5, #T_68210_row8_col6, #T_68210_row9_col0, #T_68210_row9_col1, #T_68210_row9_col2, #T_68210_row9_col3, #T_68210_row9_col4, #T_68210_row9_col5, #T_68210_row9_col6 {
#   color: yellow;
# }
# #T_68210_row10_col0, #T_68210_row10_col1, #T_68210_row10_col2, #T_68210_row10_col3, #T_68210_row10_col4, #T_68210_row10_col5, #T_68210_row10_col6, #T_68210_row11_col0, #T_68210_row11_col1, #T_68210_row11_col2, #T_68210_row11_col3, #T_68210_row11_col4, #T_68210_row11_col5, #T_68210_row11_col6, #T_68210_row12_col0, #T_68210_row12_col1, #T_68210_row12_col2, #T_68210_row12_col3, #T_68210_row12_col4, #T_68210_row12_col5, #T_68210_row12_col6, #T_68210_row13_col0, #T_68210_row13_col1, #T_68210_row13_col2, #T_68210_row13_col3, #T_68210_row13_col4, #T_68210_row13_col5, #T_68210_row13_col6, #T_68210_row14_col0, #T_68210_row14_col1, #T_68210_row14_col2, #T_68210_row14_col3, #T_68210_row14_col4, #T_68210_row14_col5, #T_68210_row14_col6 {
#   color: red;
# }
# </style>
# <table id="T_68210">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68210_level0_col0" class="col_heading level0 col0" >Total Attacks</th>
#       <th id="T_68210_level0_col1" class="col_heading level0 col1" >Avg %</th>
#       <th id="T_68210_level0_col2" class="col_heading level0 col2" >Attack 1 %</th>
#       <th id="T_68210_level0_col3" class="col_heading level0 col3" >Attack 2 %</th>
#       <th id="T_68210_level0_col4" class="col_heading level0 col4" >Attack 1 Stars</th>
#       <th id="T_68210_level0_col5" class="col_heading level0 col5" >Attack 2 Stars</th>
#       <th id="T_68210_level0_col6" class="col_heading level0 col6" >Total Stars</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68210_level0_row0" class="row_heading level0 row0" >TAYSON</th>
#       <td id="T_68210_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_68210_row0_col1" class="data row0 col1" >100.0</td>
#       <td id="T_68210_row0_col2" class="data row0 col2" >100.0</td>
#       <td id="T_68210_row0_col3" class="data row0 col3" >100.0</td>
#       <td id="T_68210_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_68210_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_68210_row0_col6" class="data row0 col6" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row1" class="row_heading level0 row1" >saulo</th>
#       <td id="T_68210_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_68210_row1_col1" class="data row1 col1" >100.0</td>
#       <td id="T_68210_row1_col2" class="data row1 col2" >100.0</td>
#       <td id="T_68210_row1_col3" class="data row1 col3" >100.0</td>
#       <td id="T_68210_row1_col4" class="data row1 col4" >3.0</td>
#       <td id="T_68210_row1_col5" class="data row1 col5" >3.0</td>
#       <td id="T_68210_row1_col6" class="data row1 col6" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row2" class="row_heading level0 row2" >kenny carlos</th>
#       <td id="T_68210_row2_col0" class="data row2 col0" >2.0</td>
#       <td id="T_68210_row2_col1" class="data row2 col1" >99.5</td>
#       <td id="T_68210_row2_col2" class="data row2 col2" >99.0</td>
#       <td id="T_68210_row2_col3" class="data row2 col3" >100.0</td>
#       <td id="T_68210_row2_col4" class="data row2 col4" >2.0</td>
#       <td id="T_68210_row2_col5" class="data row2 col5" >3.0</td>
#       <td id="T_68210_row2_col6" class="data row2 col6" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row3" class="row_heading level0 row3" >nacho</th>
#       <td id="T_68210_row3_col0" class="data row3 col0" >2.0</td>
#       <td id="T_68210_row3_col1" class="data row3 col1" >96.5</td>
#       <td id="T_68210_row3_col2" class="data row3 col2" >100.0</td>
#       <td id="T_68210_row3_col3" class="data row3 col3" >93.0</td>
#       <td id="T_68210_row3_col4" class="data row3 col4" >3.0</td>
#       <td id="T_68210_row3_col5" class="data row3 col5" >2.0</td>
#       <td id="T_68210_row3_col6" class="data row3 col6" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row4" class="row_heading level0 row4" >Krloz Fire</th>
#       <td id="T_68210_row4_col0" class="data row4 col0" >2.0</td>
#       <td id="T_68210_row4_col1" class="data row4 col1" >96.5</td>
#       <td id="T_68210_row4_col2" class="data row4 col2" >93.0</td>
#       <td id="T_68210_row4_col3" class="data row4 col3" >100.0</td>
#       <td id="T_68210_row4_col4" class="data row4 col4" >2.0</td>
#       <td id="T_68210_row4_col5" class="data row4 col5" >3.0</td>
#       <td id="T_68210_row4_col6" class="data row4 col6" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row5" class="row_heading level0 row5" >ismael</th>
#       <td id="T_68210_row5_col0" class="data row5 col0" >2.0</td>
#       <td id="T_68210_row5_col1" class="data row5 col1" >86.5</td>
#       <td id="T_68210_row5_col2" class="data row5 col2" >100.0</td>
#       <td id="T_68210_row5_col3" class="data row5 col3" >73.0</td>
#       <td id="T_68210_row5_col4" class="data row5 col4" >3.0</td>
#       <td id="T_68210_row5_col5" class="data row5 col5" >2.0</td>
#       <td id="T_68210_row5_col6" class="data row5 col6" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row6" class="row_heading level0 row6" >la mafia</th>
#       <td id="T_68210_row6_col0" class="data row6 col0" >1.0</td>
#       <td id="T_68210_row6_col1" class="data row6 col1" >100.0</td>
#       <td id="T_68210_row6_col2" class="data row6 col2" >100.0</td>
#       <td id="T_68210_row6_col3" class="data row6 col3" >0.0</td>
#       <td id="T_68210_row6_col4" class="data row6 col4" >3.0</td>
#       <td id="T_68210_row6_col5" class="data row6 col5" >0.0</td>
#       <td id="T_68210_row6_col6" class="data row6 col6" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row7" class="row_heading level0 row7" >KIKI_Games</th>
#       <td id="T_68210_row7_col0" class="data row7 col0" >1.0</td>
#       <td id="T_68210_row7_col1" class="data row7 col1" >97.0</td>
#       <td id="T_68210_row7_col2" class="data row7 col2" >97.0</td>
#       <td id="T_68210_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_68210_row7_col4" class="data row7 col4" >2.0</td>
#       <td id="T_68210_row7_col5" class="data row7 col5" >0.0</td>
#       <td id="T_68210_row7_col6" class="data row7 col6" >2.0</td>
#     </tr>
#     <tr>
#       <th id="T_68210_level0_row8" class="row_heading level0 row8" >vak</th>
#       <td id="T_68210_row8_col0" class="data row8 col0" >1.0</td>
#       <td i
