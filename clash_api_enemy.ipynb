# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import json
from pandas import json_normalize
import re

load_dotenv

token = os.getenv("API_TOKEN")

headers = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application.json'
}
response = requests.get('https://api.clashofclans.com/v1/clans/%232GLLPQYLL/currentwar', headers=headers)
response = response.json()

# %%
# with open('war1.json', "r") as json_data:
#     response = json.load(json_data)

# %%
data = json_normalize(response, record_path=['opponent', 'members'])
data
# Out:
#           tag             name  townhallLevel  mapPosition  opponentAttacks  \
# 0  #QR9GLUCLP        Mahdi✌️❤️             12            7                2
# 1    #URUQ92R          Afif ✌️             11            8                1
# 2    #PCUGCRG            khair             13            3                1
# 3  #2QQ9RQJ0P  ♥️آلَشـ❣ـہآيبـ❣             16            1                1
# 4  #G2ULQCCCC       الداينصوور             12            6                0
# 5  #PG8UYYYG2             AFIF             12            5                0
# 6  #G28LQQGL8         bigdevil             10           10                1
# 7  #99PY8V9C2         حسن ثابت             11            9                1
# 8  #YYRP8U8VY            FeHmi             16            2                0
# 9  #G8RLLL2YR            محمود             13            4                0
#
#   bestOpponentAttack.attackerTag bestOpponentAttack.defenderTag  \
# 0                      #8CRG2JR9                     #QR9GLUCLP
# 1                     #GYQ09LYRR                       #URUQ92R
# 2                      #9PRCGP9Y                       #PCUGCRG
# 3                      #9GGVU8C8                     #2QQ9RQJ0P
# 4                            NaN                            NaN
# 5                            NaN                            NaN
# 6                     #LPG2LYYGJ                     #G28LQQGL8
# 7                     #GPRURPLRG                     #99PY8V9C2
# 8                            NaN                            NaN
# 9                            NaN                            NaN
#
#    bestOpponentAttack.stars  bestOpponentAttack.destructionPercentage  \
# 0                       1.0                                      91.0
# 1                       2.0                                      94.0
# 2                       3.0                                     100.0
# 3                       2.0                                      97.0
# 4                       NaN                                       NaN
# 5                       NaN                                       NaN
# 6                       3.0                                     100.0
# 7                       3.0                                     100.0
# 8                       NaN                                       NaN
# 9                       NaN                                       NaN
#
#    bestOpponentAttack.order  bestOpponentAttack.duration  \
# 0                      18.0                        161.0
# 1                      11.0                        129.0
# 2                      19.0                         92.0
# 3                      16.0                        176.0
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                      10.0                         93.0
# 7                       9.0                        142.0
# 8                       NaN                          NaN
# 9                       NaN                          NaN
#
#                                              attacks
# 0                                                NaN
# 1  [{'attackerTag': '#URUQ92R', 'defenderTag': '#...
# 2  [{'attackerTag': '#PCUGCRG', 'defenderTag': '#...
# 3  [{'attackerTag': '#2QQ9RQJ0P', 'defenderTag': ...
# 4                                                NaN
# 5  [{'attackerTag': '#PG8UYYYG2', 'defenderTag': ...
# 6                                                NaN
# 7                                                NaN
# 8  [{'attackerTag': '#YYRP8U8VY', 'defenderTag': ...
# 9  [{'attackerTag': '#G8RLLL2YR', 'defenderTag': ...

# %%
members_df = json_normalize(response, record_path=['opponent', 'members'], meta=[])
total_members_df = members_df.copy()

# %%
attacks_df = json_normalize(
    members_df.to_dict(orient='records'),  # Convert DataFrame to dicts
    record_path='attacks',
    meta=['name'],
    meta_prefix='member_'
)
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0     #URUQ92R  #LPG2LYYGJ      3                    100      3        95
# 1     #URUQ92R  #GPRURPLRG      3                    100      4       107
# 2     #PCUGCRG   #UGRL8LV8      3                    100      5       121
# 3     #PCUGCRG   #8Q8UQL8Y      3                    100      6        69
# 4   #2QQ9RQJ0P   #9GGVU8C8      1                     78     12       128
# 5   #2QQ9RQJ0P   #9PRCGP9Y      2                     52     15        49
# 6   #PG8UYYYG2   #8CRG2JR9      3                    100      1        96
# 7   #PG8UYYYG2  #GYQ09LYRR      3                    100      2        92
# 8   #YYRP8U8VY   #9GGVU8C8      2                     75      7        63
# 9   #YYRP8U8VY   #9PRCGP9Y      3                    100      8        87
# 10  #G8RLLL2YR  #G222UU009      3                    100     13        84
# 11  #G8RLLL2YR  #GGV0JPQ2C      3                    100     14        60
#
#         member_name
# 0           Afif ✌️
# 1           Afif ✌️
# 2             khair
# 3             khair
# 4   ♥️آلَشـ❣ـہآيبـ❣
# 5   ♥️آلَشـ❣ـہآيبـ❣
# 6              AFIF
# 7              AFIF
# 8             FeHmi
# 9             FeHmi
# 10            محمود
# 11            محمود

# %%
attacks_df['attack_num'] = attacks_df.groupby('member_name').cumcount() + 1
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0     #URUQ92R  #LPG2LYYGJ      3                    100      3        95
# 1     #URUQ92R  #GPRURPLRG      3                    100      4       107
# 2     #PCUGCRG   #UGRL8LV8      3                    100      5       121
# 3     #PCUGCRG   #8Q8UQL8Y      3                    100      6        69
# 4   #2QQ9RQJ0P   #9GGVU8C8      1                     78     12       128
# 5   #2QQ9RQJ0P   #9PRCGP9Y      2                     52     15        49
# 6   #PG8UYYYG2   #8CRG2JR9      3                    100      1        96
# 7   #PG8UYYYG2  #GYQ09LYRR      3                    100      2        92
# 8   #YYRP8U8VY   #9GGVU8C8      2                     75      7        63
# 9   #YYRP8U8VY   #9PRCGP9Y      3                    100      8        87
# 10  #G8RLLL2YR  #G222UU009      3                    100     13        84
# 11  #G8RLLL2YR  #GGV0JPQ2C      3                    100     14        60
#
#         member_name  attack_num
# 0           Afif ✌️           1
# 1           Afif ✌️           2
# 2             khair           1
# 3             khair           2
# 4   ♥️آلَشـ❣ـہآيبـ❣           1
# 5   ♥️آلَشـ❣ـہآيبـ❣           2
# 6              AFIF           1
# 7              AFIF           2
# 8             FeHmi           1
# 9             FeHmi           2
# 10            محمود           1
# 11            محمود           2

# %%
attacks_df['total_attacks'] = attacks_df.groupby('member_name')['attack_num'].transform('max')
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0     #URUQ92R  #LPG2LYYGJ      3                    100      3        95
# 1     #URUQ92R  #GPRURPLRG      3                    100      4       107
# 2     #PCUGCRG   #UGRL8LV8      3                    100      5       121
# 3     #PCUGCRG   #8Q8UQL8Y      3                    100      6        69
# 4   #2QQ9RQJ0P   #9GGVU8C8      1                     78     12       128
# 5   #2QQ9RQJ0P   #9PRCGP9Y      2                     52     15        49
# 6   #PG8UYYYG2   #8CRG2JR9      3                    100      1        96
# 7   #PG8UYYYG2  #GYQ09LYRR      3                    100      2        92
# 8   #YYRP8U8VY   #9GGVU8C8      2                     75      7        63
# 9   #YYRP8U8VY   #9PRCGP9Y      3                    100      8        87
# 10  #G8RLLL2YR  #G222UU009      3                    100     13        84
# 11  #G8RLLL2YR  #GGV0JPQ2C      3                    100     14        60
#
#         member_name  attack_num  total_attacks
# 0           Afif ✌️           1              2
# 1           Afif ✌️           2              2
# 2             khair           1              2
# 3             khair           2              2
# 4   ♥️آلَشـ❣ـہآيبـ❣           1              2
# 5   ♥️آلَشـ❣ـہآيبـ❣           2              2
# 6              AFIF           1              2
# 7              AFIF           2              2
# 8             FeHmi           1              2
# 9             FeHmi           2              2
# 10            محمود           1              2
# 11            محمود           2              2

# %%
total_attacks_df = attacks_df[['member_name', 'total_attacks']].drop_duplicates().set_index('member_name')
total_attacks_df
# Out:
#                  total_attacks
# member_name
# Afif ✌️                      2
# khair                        2
# ♥️آلَشـ❣ـہآيبـ❣              2
# AFIF                         2
# FeHmi                        2
# محمود                        2

# %%
pivot_df = attacks_df.pivot_table(
    index=['member_name'], 
    columns='attack_num', 
    values=['attackerTag', 'defenderTag', 'stars', 'destructionPercentage', 'order', 'duration'], 
    aggfunc='first'
)
pivot_df
# Out:
#                 attackerTag             defenderTag              \
# attack_num                1           2           1           2
# member_name
# AFIF             #PG8UYYYG2  #PG8UYYYG2   #8CRG2JR9  #GYQ09LYRR
# Afif ✌️            #URUQ92R    #URUQ92R  #LPG2LYYGJ  #GPRURPLRG
# FeHmi            #YYRP8U8VY  #YYRP8U8VY   #9GGVU8C8   #9PRCGP9Y
# khair              #PCUGCRG    #PCUGCRG   #UGRL8LV8   #8Q8UQL8Y
# محمود            #G8RLLL2YR  #G8RLLL2YR  #G222UU009  #GGV0JPQ2C
# ♥️آلَشـ❣ـہآيبـ❣  #2QQ9RQJ0P  #2QQ9RQJ0P   #9GGVU8C8   #9PRCGP9Y
#
#                 destructionPercentage      duration      order     stars
# attack_num                          1    2        1    2     1   2     1  2
# member_name
# AFIF                              100  100       96   92     1   2     3  3
# Afif ✌️                           100  100       95  107     3   4     3  3
# FeHmi                              75  100       63   87     7   8     2  3
# khair                             100  100      121   69     5   6     3  3
# محمود                             100  100       84   60    13  14     3  3
# ♥️آلَشـ❣ـہآيبـ❣                    78   52      128   49    12  15     1  2

# %%
pivot_df.columns = [f"{col[0]}_{col[1]}" for col in pivot_df.columns]

# %%
def extract_text_and_number(column_name):
    match = re.match(r'(.+?)_(\d+)', column_name)
    return (int(match.group(2)), match.group(1)) if match else (float('inf'), column_name)

# %%
sorted_columns = sorted(pivot_df.columns, key=lambda x: extract_text_and_number(x))
sorted_columns
# Out:
# ['attackerTag_1',
#  'defenderTag_1',
#  'destructionPercentage_1',
#  'duration_1',
#  'order_1',
#  'stars_1',
#  'attackerTag_2',
#  'defenderTag_2',
#  'destructionPercentage_2',
#  'duration_2',
#  'order_2',
#  'stars_2']

# %%
pivot_df = pivot_df[sorted_columns]

# %%
final_df = pivot_df.join(total_attacks_df)
final_df
# Out:
#                 attackerTag_1 defenderTag_1  destructionPercentage_1  \
# member_name
# AFIF               #PG8UYYYG2     #8CRG2JR9                      100
# Afif ✌️              #URUQ92R    #LPG2LYYGJ                      100
# FeHmi              #YYRP8U8VY     #9GGVU8C8                       75
# khair                #PCUGCRG     #UGRL8LV8                      100
# محمود              #G8RLLL2YR    #G222UU009                      100
# ♥️آلَشـ❣ـہآيبـ❣    #2QQ9RQJ0P     #9GGVU8C8                       78
#
#                  duration_1  order_1  stars_1 attackerTag_2 defenderTag_2  \
# member_name
# AFIF                     96        1        3    #PG8UYYYG2    #GYQ09LYRR
# Afif ✌️                  95        3        3      #URUQ92R    #GPRURPLRG
# FeHmi                    63        7        2    #YYRP8U8VY     #9PRCGP9Y
# khair                   121        5        3      #PCUGCRG     #8Q8UQL8Y
# محمود                    84       13        3    #G8RLLL2YR    #GGV0JPQ2C
# ♥️آلَشـ❣ـہآيبـ❣         128       12        1    #2QQ9RQJ0P     #9PRCGP9Y
#
#                  destructionPercentage_2  duration_2  order_2  stars_2  \
# member_name
# AFIF                                 100          92        2        3
# Afif ✌️                              100         107        4        3
# FeHmi                                100          87        8        3
# khair                                100          69        6        3
# محمود                                100          60       14        3
# ♥️آلَشـ❣ـہآيبـ❣                       52          49       15        2
#
#                  total_attacks
# member_name
# AFIF                         2
# Afif ✌️                      2
# FeHmi                        2
# khair                        2
# محمود                        2
# ♥️آلَشـ❣ـہآيبـ❣              2

# %%
new_name_df = final_df
new_name_df['Avg %'] = new_name_df[['destructionPercentage_1', 'destructionPercentage_2']].mean(axis=1)
new_name_df['Total Stars'] = new_name_df[["stars_1", "stars_2"]].sum(axis=1)

# %%
new_order = ['total_attacks', 'Avg %', 'destructionPercentage_1', 'destructionPercentage_2', 
             'stars_1', 'stars_2', 'Total Stars']
new_name_df = new_name_df[new_order]
final_name_df = new_name_df.rename(columns={'destructionPercentage_1' : 'Attack 1 %', 'destructionPercentage_2' : 'Attack 2 %', 
                                            'stars_1' : 'Attack 1 Stars', 'stars_2' : 'Attack 2 Stars', 'total_attacks' : 'Total Attacks'})
final_name_df
# Out:
#                  Total Attacks  Avg %  Attack 1 %  Attack 2 %  Attack 1 Stars  \
# member_name
# AFIF                         2  100.0         100         100               3
# Afif ✌️                      2  100.0         100         100               3
# FeHmi                        2   87.5          75         100               2
# khair                        2  100.0         100         100               3
# محمود                        2  100.0         100         100               3
# ♥️آلَشـ❣ـہآيبـ❣              2   65.0          78          52               1
#
#                  Attack 2 Stars  Total Stars
# member_name
# AFIF                          3            6
# Afif ✌️                       3            6
# FeHmi                         3            5
# khair                         3            6
# محمود                         3            6
# ♥️آلَشـ❣ـہآيبـ❣               2            3

# %%
try:
    total_members_df = total_members_df.set_index('name')
except KeyError:
    pass

# %%
final_name_df["Total Clan Stars"] = final_name_df['Total Stars'].sum()
combined_df = final_name_df.reindex(total_members_df.index)
combined_df.fillna(0, inplace=True)
combined_df.sort_values(["Total Attacks", 'Total Stars', 'Avg %'], ascending=False, inplace=True)

# %%
def colors(row):
    if row['Total Attacks'] == 2.0:
        color = "rgb(0,255,0)"
    elif row['Total Attacks'] == 1.0:
        color = "yellow"
    else:
        color = "red"
    return [f'color: {color}'] * len(row)

# %%
styled_df = combined_df.style.apply(colors, axis=1).format('{:.1f}')
styled_df
# Out:
# <style type="text/css">
# #T_1198d_row0_col0, #T_1198d_row0_col1, #T_1198d_row0_col2, #T_1198d_row0_col3, #T_1198d_row0_col4, #T_1198d_row0_col5, #T_1198d_row0_col6, #T_1198d_row0_col7, #T_1198d_row1_col0, #T_1198d_row1_col1, #T_1198d_row1_col2, #T_1198d_row1_col3, #T_1198d_row1_col4, #T_1198d_row1_col5, #T_1198d_row1_col6, #T_1198d_row1_col7, #T_1198d_row2_col0, #T_1198d_row2_col1, #T_1198d_row2_col2, #T_1198d_row2_col3, #T_1198d_row2_col4, #T_1198d_row2_col5, #T_1198d_row2_col6, #T_1198d_row2_col7, #T_1198d_row3_col0, #T_1198d_row3_col1, #T_1198d_row3_col2, #T_1198d_row3_col3, #T_1198d_row3_col4, #T_1198d_row3_col5, #T_1198d_row3_col6, #T_1198d_row3_col7, #T_1198d_row4_col0, #T_1198d_row4_col1, #T_1198d_row4_col2, #T_1198d_row4_col3, #T_1198d_row4_col4, #T_1198d_row4_col5, #T_1198d_row4_col6, #T_1198d_row4_col7, #T_1198d_row5_col0, #T_1198d_row5_col1, #T_1198d_row5_col2, #T_1198d_row5_col3, #T_1198d_row5_col4, #T_1198d_row5_col5, #T_1198d_row5_col6, #T_1198d_row5_col7 {
#   color: rgb(0,255,0);
# }
# #T_1198d_row6_col0, #T_1198d_row6_col1, #T_1198d_row6_col2, #T_1198d_row6_col3, #T_1198d_row6_col4, #T_1198d_row6_col5, #T_1198d_row6_col6, #T_1198d_row6_col7, #T_1198d_row7_col0, #T_1198d_row7_col1, #T_1198d_row7_col2, #T_1198d_row7_col3, #T_1198d_row7_col4, #T_1198d_row7_col5, #T_1198d_row7_col6, #T_1198d_row7_col7, #T_1198d_row8_col0, #T_1198d_row8_col1, #T_1198d_row8_col2, #T_1198d_row8_col3, #T_1198d_row8_col4, #T_1198d_row8_col5, #T_1198d_row8_col6, #T_1198d_row8_col7, #T_1198d_row9_col0, #T_1198d_row9_col1, #T_1198d_row9_col2, #T_1198d_row9_col3, #T_1198d_row9_col4, #T_1198d_row9_col5, #T_1198d_row9_col6, #T_1198d_row9_col7 {
#   color: red;
# }
# </style>
# <table id="T_1198d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1198d_level0_col0" class="col_heading level0 col0" >Total Attacks</th>
#       <th id="T_1198d_level0_col1" class="col_heading level0 col1" >Avg %</th>
#       <th id="T_1198d_level0_col2" class="col_heading level0 col2" >Attack 1 %</th>
#       <th id="T_1198d_level0_col3" class="col_heading level0 col3" >Attack 2 %</th>
#       <th id="T_1198d_level0_col4" class="col_heading level0 col4" >Attack 1 Stars</th>
#       <th id="T_1198d_level0_col5" class="col_heading level0 col5" >Attack 2 Stars</th>
#       <th id="T_1198d_level0_col6" class="col_heading level0 col6" >Total Stars</th>
#       <th id="T_1198d_level0_col7" class="col_heading level0 col7" >Total Clan Stars</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1198d_level0_row0" class="row_heading level0 row0" >Afif ✌️</th>
#       <td id="T_1198d_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_1198d_row0_col1" class="data row0 col1" >100.0</td>
#       <td id="T_1198d_row0_col2" class="data row0 col2" >100.0</td>
#       <td id="T_1198d_row0_col3" class="data row0 col3" >100.0</td>
#       <td id="T_1198d_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_1198d_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_1198d_row0_col6" class="data row0 col6" >6.0</td>
#       <td id="T_1198d_row0_col7" class="data row0 col7" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row1" class="row_heading level0 row1" >khair</th>
#       <td id="T_1198d_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_1198d_row1_col1" class="data row1 col1" >100.0</td>
#       <td id="T_1198d_row1_col2" class="data row1 col2" >100.0</td>
#       <td id="T_1198d_row1_col3" class="data row1 col3" >100.0</td>
#       <td id="T_1198d_row1_col4" class="data row1 col4" >3.0</td>
#       <td id="T_1198d_row1_col5" class="data row1 col5" >3.0</td>
#       <td id="T_1198d_row1_col6" class="data row1 col6" >6.0</td>
#       <td id="T_1198d_row1_col7" class="data row1 col7" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row2" class="row_heading level0 row2" >AFIF</th>
#       <td id="T_1198d_row2_col0" class="data row2 col0" >2.0</td>
#       <td id="T_1198d_row2_col1" class="data row2 col1" >100.0</td>
#       <td id="T_1198d_row2_col2" class="data row2 col2" >100.0</td>
#       <td id="T_1198d_row2_col3" class="data row2 col3" >100.0</td>
#       <td id="T_1198d_row2_col4" class="data row2 col4" >3.0</td>
#       <td id="T_1198d_row2_col5" class="data row2 col5" >3.0</td>
#       <td id="T_1198d_row2_col6" class="data row2 col6" >6.0</td>
#       <td id="T_1198d_row2_col7" class="data row2 col7" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row3" class="row_heading level0 row3" >محمود</th>
#       <td id="T_1198d_row3_col0" class="data row3 col0" >2.0</td>
#       <td id="T_1198d_row3_col1" class="data row3 col1" >100.0</td>
#       <td id="T_1198d_row3_col2" class="data row3 col2" >100.0</td>
#       <td id="T_1198d_row3_col3" class="data row3 col3" >100.0</td>
#       <td id="T_1198d_row3_col4" class="data row3 col4" >3.0</td>
#       <td id="T_1198d_row3_col5" class="data row3 col5" >3.0</td>
#       <td id="T_1198d_row3_col6" class="data row3 col6" >6.0</td>
#       <td id="T_1198d_row3_col7" class="data row3 col7" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row4" class="row_heading level0 row4" >FeHmi</th>
#       <td id="T_1198d_row4_col0" class="data row4 col0" >2.0</td>
#       <td id="T_1198d_row4_col1" class="data row4 col1" >87.5</td>
#       <td id="T_1198d_row4_col2" class="data row4 col2" >75.0</td>
#       <td id="T_1198d_row4_col3" class="data row4 col3" >100.0</td>
#       <td id="T_1198d_row4_col4" class="data row4 col4" >2.0</td>
#       <td id="T_1198d_row4_col5" class="data row4 col5" >3.0</td>
#       <td id="T_1198d_row4_col6" class="data row4 col6" >5.0</td>
#       <td id="T_1198d_row4_col7" class="data row4 col7" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row5" class="row_heading level0 row5" >♥️آلَشـ❣ـہآيبـ❣</th>
#       <td id="T_1198d_row5_col0" class="data row5 col0" >2.0</td>
#       <td id="T_1198d_row5_col1" class="data row5 col1" >65.0</td>
#       <td id="T_1198d_row5_col2" class="data row5 col2" >78.0</td>
#       <td id="T_1198d_row5_col3" class="data row5 col3" >52.0</td>
#       <td id="T_1198d_row5_col4" class="data row5 col4" >1.0</td>
#       <td id="T_1198d_row5_col5" class="data row5 col5" >2.0</td>
#       <td id="T_1198d_row5_col6" class="data row5 col6" >3.0</td>
#       <td id="T_1198d_row5_col7" class="data row5 col7" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row6" class="row_heading level0 row6" >Mahdi✌️❤️</th>
#       <td id="T_1198d_row6_col0" class="data row6 col0" >0.0</td>
#       <td id="T_1198d_row6_col1" class="data row6 col1" >0.0</td>
#       <td id="T_1198d_row6_col2" class="data row6 col2" >0.0</td>
#       <td id="T_1198d_row6_col3" class="data row6 col3" >0.0</td>
#       <td id="T_1198d_row6_col4" class="data row6 col4" >0.0</td>
#       <td id="T_1198d_row6_col5" class="data row6 col5" >0.0</td>
#       <td id="T_1198d_row6_col6" class="data row6 col6" >0.0</td>
#       <td id="T_1198d_row6_col7" class="data row6 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row7" class="row_heading level0 row7" >الداينصوور</th>
#       <td id="T_1198d_row7_col0" class="data row7 col0" >0.0</td>
#       <td id="T_1198d_row7_col1" class="data row7 col1" >0.0</td>
#       <td id="T_1198d_row7_col2" class="data row7 col2" >0.0</td>
#       <td id="T_1198d_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_1198d_row7_col4" class="data row7 col4" >0.0</td>
#       <td id="T_1198d_row7_col5" class="data row7 col5" >0.0</td>
#       <td id="T_1198d_row7_col6" class="data row7 col6" >0.0</td>
#       <td id="T_1198d_row7_col7" class="data row7 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_1198d_level0_row8" class="row_he
