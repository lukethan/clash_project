# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import json
from pandas import json_normalize
import re

load_dotenv

token = os.getenv("API_TOKEN")

headers = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application.json'
}
response = requests.get('https://api.clashofclans.com/v1/clans/%232GLLPQYLL/currentwar', headers=headers)
response = response.json()

# %%
data = json_normalize(response, record_path=['clan', 'members'])
data
# Out:
#            tag           name  townhallLevel  mapPosition  \
# 0    #UGRL8LV8        mcnasty             13            5
# 1    #8Q8UQL8Y   NMbaseball22             11            9
# 2    #8CRG2JR9      MeekMulli             12            6
# 3   #G222UU009      Ben Dover             11           12
# 4     #899PLPG        cordell             14            4
# 5    #2RR2PVRG    Alwayz High             15            2
# 6    #9PRCGP9Y           Luke             15            3
# 7    #9GGVU8C8   Shamrock 2.0             16            1
# 8   #L99GG88LG        BigAedo             12            8
# 9   #GYQ09LYRR        winston             12            7
# 10  #GPC0JCLPG           Tony             10           14
# 11  #LPG2LYYGJ         Drippy             11           11
# 12  #GGV0JPQ2C       MewThree             10           15
# 13  #GPRURPLRG  Wreckit Ralph             11           13
# 14  #P22YPY90V          noich             11           10
#
#                                               attacks  opponentAttacks  \
# 0   [{'attackerTag': '#UGRL8LV8', 'defenderTag': '...                2
# 1                                                 NaN                1
# 2   [{'attackerTag': '#8CRG2JR9', 'defenderTag': '...                1
# 3   [{'attackerTag': '#G222UU009', 'defenderTag': ...                1
# 4                                                 NaN                1
# 5                                                 NaN                1
# 6   [{'attackerTag': '#9PRCGP9Y', 'defenderTag': '...                1
# 7   [{'attackerTag': '#9GGVU8C8', 'defenderTag': '...                1
# 8                                                 NaN                1
# 9   [{'attackerTag': '#GYQ09LYRR', 'defenderTag': ...                1
# 10  [{'attackerTag': '#GPC0JCLPG', 'defenderTag': ...                1
# 11  [{'attackerTag': '#LPG2LYYGJ', 'defenderTag': ...                1
# 12  [{'attackerTag': '#GGV0JPQ2C', 'defenderTag': ...                1
# 13  [{'attackerTag': '#GPRURPLRG', 'defenderTag': ...                1
# 14                                                NaN                1
#
#    bestOpponentAttack.attackerTag bestOpponentAttack.defenderTag  \
# 0                      #2JGVRGVRV                      #UGRL8LV8
# 1                      #GL2GC2PQ8                      #8Q8UQL8Y
# 2                      #2JGVRGVRV                      #8CRG2JR9
# 3                      #GY9CPCLC8                     #G222UU009
# 4                      #Y9CJRGJYC                       #899PLPG
# 5                      #9R8CYRJP9                      #2RR2PVRG
# 6                      #Y9CJRGJYC                      #9PRCGP9Y
# 7                      #9R8CYRJP9                      #9GGVU8C8
# 8                      #9VC2P0CQR                     #L99GG88LG
# 9                      #9VC2P0CQR                     #GYQ09LYRR
# 10                     #GY9CPCLC8                     #GPC0JCLPG
# 11                      #P2JGVYRP                     #LPG2LYYGJ
# 12                     #LJVUCC9RC                     #GGV0JPQ2C
# 13                     #GL2YCLVCC                     #GPRURPLRG
# 14                     #GL2GC2PQ8                     #P22YPY90V
#
#     bestOpponentAttack.stars  bestOpponentAttack.destructionPercentage  \
# 0                          2                                        93
# 1                          3                                       100
# 2                          3                                       100
# 3                          3                                       100
# 4                          3                                       100
# 5                          3                                       100
# 6                          2                                        99
# 7                          2                                        73
# 8                          3                                       100
# 9                          3                                       100
# 10                         3                                       100
# 11                         2                                        87
# 12                         2                                        97
# 13                         3                                       100
# 14                         2                                        93
#
#     bestOpponentAttack.order  bestOpponentAttack.duration
# 0                         14                          173
# 1                          8                          150
# 2                         15                          127
# 3                         19                          144
# 4                          5                          122
# 5                          3                          145
# 6                          4                          180
# 7                         22                          147
# 8                         17                          130
# 9                         16                           91
# 10                        18                          124
# 11                        23                          180
# 12                         1                          180
# 13                        27                          139
# 14                         9                          180

# %%
members_df = json_normalize(response, record_path=['clan', 'members'], meta=[])
total_members_df = members_df.copy()

# %%
attacks_df = json_normalize(
    members_df.to_dict(orient='records'),  # Convert DataFrame to dicts
    record_path='attacks',
    meta=['name'],
    meta_prefix='member_'
)
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0    #UGRL8LV8   #P2JGVYRP      3                    100     28        75
# 1    #UGRL8LV8  #LCGR0Y2RC      3                    100     30        96
# 2    #8CRG2JR9  #LCGR0Y2RC      1                     83     10       141
# 3   #G222UU009  #G8JQCRRCR      3                    100     20       118
# 4   #G222UU009  #GL2GC2PQ8      1                     76     32       113
# 5    #9PRCGP9Y  #82CY8YUUJ      3                    100     31       112
# 6    #9PRCGP9Y  #9VC2P0CQR      3                    100     33       110
# 7    #9GGVU8C8  #9R8CYRJP9      1                     77     21       109
# 8    #9GGVU8C8  #Y9CJRGJYC      2                     97     24       180
# 9   #GYQ09LYRR  #LV2990URP      3                    100     12       124
# 10  #GYQ09LYRR  #GL2GC2PQ8      1                     88     13        87
# 11  #GPC0JCLPG  #LJVUCC9RC      3                    100      6       114
# 12  #GPC0JCLPG  #GLPJPGPQ2      2                     65      7        89
# 13  #LPG2LYYGJ  #GL2YCLVCC      1                     45     11        92
# 14  #GGV0JPQ2C  #GL2YCLVCC      1                     47     25        93
# 15  #GPRURPLRG  #GY9CPCLC8      3                    100      2       102
# 16  #GPRURPLRG  #GLPJPGPQ2      3                    100     29       132
#
#       member_name
# 0         mcnasty
# 1         mcnasty
# 2       MeekMulli
# 3       Ben Dover
# 4       Ben Dover
# 5            Luke
# 6            Luke
# 7    Shamrock 2.0
# 8    Shamrock 2.0
# 9         winston
# 10        winston
# 11           Tony
# 12           Tony
# 13         Drippy
# 14       MewThree
# 15  Wreckit Ralph
# 16  Wreckit Ralph

# %%
attacks_df['attack_num'] = attacks_df.groupby('member_name').cumcount() + 1
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0    #UGRL8LV8   #P2JGVYRP      3                    100     28        75
# 1    #UGRL8LV8  #LCGR0Y2RC      3                    100     30        96
# 2    #8CRG2JR9  #LCGR0Y2RC      1                     83     10       141
# 3   #G222UU009  #G8JQCRRCR      3                    100     20       118
# 4   #G222UU009  #GL2GC2PQ8      1                     76     32       113
# 5    #9PRCGP9Y  #82CY8YUUJ      3                    100     31       112
# 6    #9PRCGP9Y  #9VC2P0CQR      3                    100     33       110
# 7    #9GGVU8C8  #9R8CYRJP9      1                     77     21       109
# 8    #9GGVU8C8  #Y9CJRGJYC      2                     97     24       180
# 9   #GYQ09LYRR  #LV2990URP      3                    100     12       124
# 10  #GYQ09LYRR  #GL2GC2PQ8      1                     88     13        87
# 11  #GPC0JCLPG  #LJVUCC9RC      3                    100      6       114
# 12  #GPC0JCLPG  #GLPJPGPQ2      2                     65      7        89
# 13  #LPG2LYYGJ  #GL2YCLVCC      1                     45     11        92
# 14  #GGV0JPQ2C  #GL2YCLVCC      1                     47     25        93
# 15  #GPRURPLRG  #GY9CPCLC8      3                    100      2       102
# 16  #GPRURPLRG  #GLPJPGPQ2      3                    100     29       132
#
#       member_name  attack_num
# 0         mcnasty           1
# 1         mcnasty           2
# 2       MeekMulli           1
# 3       Ben Dover           1
# 4       Ben Dover           2
# 5            Luke           1
# 6            Luke           2
# 7    Shamrock 2.0           1
# 8    Shamrock 2.0           2
# 9         winston           1
# 10        winston           2
# 11           Tony           1
# 12           Tony           2
# 13         Drippy           1
# 14       MewThree           1
# 15  Wreckit Ralph           1
# 16  Wreckit Ralph           2

# %%
attacks_df['total_attacks'] = attacks_df.groupby('member_name')['attack_num'].transform('max')
attacks_df
# Out:
#    attackerTag defenderTag  stars  destructionPercentage  order  duration  \
# 0    #UGRL8LV8   #P2JGVYRP      3                    100     28        75
# 1    #UGRL8LV8  #LCGR0Y2RC      3                    100     30        96
# 2    #8CRG2JR9  #LCGR0Y2RC      1                     83     10       141
# 3   #G222UU009  #G8JQCRRCR      3                    100     20       118
# 4   #G222UU009  #GL2GC2PQ8      1                     76     32       113
# 5    #9PRCGP9Y  #82CY8YUUJ      3                    100     31       112
# 6    #9PRCGP9Y  #9VC2P0CQR      3                    100     33       110
# 7    #9GGVU8C8  #9R8CYRJP9      1                     77     21       109
# 8    #9GGVU8C8  #Y9CJRGJYC      2                     97     24       180
# 9   #GYQ09LYRR  #LV2990URP      3                    100     12       124
# 10  #GYQ09LYRR  #GL2GC2PQ8      1                     88     13        87
# 11  #GPC0JCLPG  #LJVUCC9RC      3                    100      6       114
# 12  #GPC0JCLPG  #GLPJPGPQ2      2                     65      7        89
# 13  #LPG2LYYGJ  #GL2YCLVCC      1                     45     11        92
# 14  #GGV0JPQ2C  #GL2YCLVCC      1                     47     25        93
# 15  #GPRURPLRG  #GY9CPCLC8      3                    100      2       102
# 16  #GPRURPLRG  #GLPJPGPQ2      3                    100     29       132
#
#       member_name  attack_num  total_attacks
# 0         mcnasty           1              2
# 1         mcnasty           2              2
# 2       MeekMulli           1              1
# 3       Ben Dover           1              2
# 4       Ben Dover           2              2
# 5            Luke           1              2
# 6            Luke           2              2
# 7    Shamrock 2.0           1              2
# 8    Shamrock 2.0           2              2
# 9         winston           1              2
# 10        winston           2              2
# 11           Tony           1              2
# 12           Tony           2              2
# 13         Drippy           1              1
# 14       MewThree           1              1
# 15  Wreckit Ralph           1              2
# 16  Wreckit Ralph           2              2

# %%
total_attacks_df = attacks_df[['member_name', 'total_attacks']].drop_duplicates().set_index('member_name')
total_attacks_df
# Out:
#                total_attacks
# member_name
# mcnasty                    2
# MeekMulli                  1
# Ben Dover                  2
# Luke                       2
# Shamrock 2.0               2
# winston                    2
# Tony                       2
# Drippy                     1
# MewThree                   1
# Wreckit Ralph              2

# %%
pivot_df = attacks_df.pivot_table(
    index=['member_name'], 
    columns='attack_num', 
    values=['attackerTag', 'defenderTag', 'stars', 'destructionPercentage', 'order', 'duration'], 
    aggfunc='first'
)
pivot_df
# Out:
#               attackerTag             defenderTag              \
# attack_num              1           2           1           2
# member_name
# Ben Dover      #G222UU009  #G222UU009  #G8JQCRRCR  #GL2GC2PQ8
# Drippy         #LPG2LYYGJ         NaN  #GL2YCLVCC         NaN
# Luke            #9PRCGP9Y   #9PRCGP9Y  #82CY8YUUJ  #9VC2P0CQR
# MeekMulli       #8CRG2JR9         NaN  #LCGR0Y2RC         NaN
# MewThree       #GGV0JPQ2C         NaN  #GL2YCLVCC         NaN
# Shamrock 2.0    #9GGVU8C8   #9GGVU8C8  #9R8CYRJP9  #Y9CJRGJYC
# Tony           #GPC0JCLPG  #GPC0JCLPG  #LJVUCC9RC  #GLPJPGPQ2
# Wreckit Ralph  #GPRURPLRG  #GPRURPLRG  #GY9CPCLC8  #GLPJPGPQ2
# mcnasty         #UGRL8LV8   #UGRL8LV8   #P2JGVYRP  #LCGR0Y2RC
# winston        #GYQ09LYRR  #GYQ09LYRR  #LV2990URP  #GL2GC2PQ8
#
#               destructionPercentage        duration        order       stars  \
# attack_num                        1      2        1      2     1     2     1
# member_name
# Ben Dover                    100.00  76.00   118.00 113.00 20.00 32.00  3.00
# Drippy                        45.00    NaN    92.00    NaN 11.00   NaN  1.00
# Luke                         100.00 100.00   112.00 110.00 31.00 33.00  3.00
# MeekMulli                     83.00    NaN   141.00    NaN 10.00   NaN  1.00
# MewThree                      47.00    NaN    93.00    NaN 25.00   NaN  1.00
# Shamrock 2.0                  77.00  97.00   109.00 180.00 21.00 24.00  1.00
# Tony                         100.00  65.00   114.00  89.00  6.00  7.00  3.00
# Wreckit Ralph                100.00 100.00   102.00 132.00  2.00 29.00  3.00
# mcnasty                      100.00 100.00    75.00  96.00 28.00 30.00  3.00
# winston                      100.00  88.00   124.00  87.00 12.00 13.00  3.00
#
#
# attack_num       2
# member_name
# Ben Dover     1.00
# Drippy         NaN
# Luke          3.00
# MeekMulli      NaN
# MewThree       NaN
# Shamrock 2.0  2.00
# Tony          2.00
# Wreckit Ralph 3.00
# mcnasty       3.00
# winston       1.00

# %%
pivot_df.columns = [f"{col[0]}_{col[1]}" for col in pivot_df.columns]

# %%
def extract_text_and_number(column_name):
    match = re.match(r'(.+?)_(\d+)', column_name)
    return (int(match.group(2)), match.group(1)) if match else (float('inf'), column_name)

# %%
sorted_columns = sorted(pivot_df.columns, key=lambda x: extract_text_and_number(x))
sorted_columns
# Out:
# ['attackerTag_1',
#  'defenderTag_1',
#  'destructionPercentage_1',
#  'duration_1',
#  'order_1',
#  'stars_1',
#  'attackerTag_2',
#  'defenderTag_2',
#  'destructionPercentage_2',
#  'duration_2',
#  'order_2',
#  'stars_2']

# %%
pivot_df = pivot_df[sorted_columns]

# %%
final_df = pivot_df.join(total_attacks_df)
final_df
# Out:
#               attackerTag_1 defenderTag_1  destructionPercentage_1  \
# member_name
# Ben Dover        #G222UU009    #G8JQCRRCR                   100.00
# Drippy           #LPG2LYYGJ    #GL2YCLVCC                    45.00
# Luke              #9PRCGP9Y    #82CY8YUUJ                   100.00
# MeekMulli         #8CRG2JR9    #LCGR0Y2RC                    83.00
# MewThree         #GGV0JPQ2C    #GL2YCLVCC                    47.00
# Shamrock 2.0      #9GGVU8C8    #9R8CYRJP9                    77.00
# Tony             #GPC0JCLPG    #LJVUCC9RC                   100.00
# Wreckit Ralph    #GPRURPLRG    #GY9CPCLC8                   100.00
# mcnasty           #UGRL8LV8     #P2JGVYRP                   100.00
# winston          #GYQ09LYRR    #LV2990URP                   100.00
#
#                duration_1  order_1  stars_1 attackerTag_2 defenderTag_2  \
# member_name
# Ben Dover          118.00    20.00     3.00    #G222UU009    #GL2GC2PQ8
# Drippy              92.00    11.00     1.00           NaN           NaN
# Luke               112.00    31.00     3.00     #9PRCGP9Y    #9VC2P0CQR
# MeekMulli          141.00    10.00     1.00           NaN           NaN
# MewThree            93.00    25.00     1.00           NaN           NaN
# Shamrock 2.0       109.00    21.00     1.00     #9GGVU8C8    #Y9CJRGJYC
# Tony               114.00     6.00     3.00    #GPC0JCLPG    #GLPJPGPQ2
# Wreckit Ralph      102.00     2.00     3.00    #GPRURPLRG    #GLPJPGPQ2
# mcnasty             75.00    28.00     3.00     #UGRL8LV8    #LCGR0Y2RC
# winston            124.00    12.00     3.00    #GYQ09LYRR    #GL2GC2PQ8
#
#                destructionPercentage_2  duration_2  order_2  stars_2  \
# member_name
# Ben Dover                        76.00      113.00    32.00     1.00
# Drippy                             NaN         NaN      NaN      NaN
# Luke                            100.00      110.00    33.00     3.00
# MeekMulli                          NaN         NaN      NaN      NaN
# MewThree                           NaN         NaN      NaN      NaN
# Shamrock 2.0                     97.00      180.00    24.00     2.00
# Tony                             65.00       89.00     7.00     2.00
# Wreckit Ralph                   100.00      132.00    29.00     3.00
# mcnasty                         100.00       96.00    30.00     3.00
# winston                          88.00       87.00    13.00     1.00
#
#                total_attacks
# member_name
# Ben Dover                  2
# Drippy                     1
# Luke                       2
# MeekMulli                  1
# MewThree                   1
# Shamrock 2.0               2
# Tony                       2
# Wreckit Ralph              2
# mcnasty                    2
# winston                    2

# %%
new_name_df = final_df
new_name_df['Avg %'] = new_name_df[['destructionPercentage_1', 'destructionPercentage_2']].mean(axis=1)
new_name_df['Total Stars'] = new_name_df[["stars_1", "stars_2"]].sum(axis=1)

# %%
new_order = ['total_attacks', 'Avg %', 'destructionPercentage_1', 'destructionPercentage_2', 
             'stars_1', 'stars_2', 'Total Stars']
new_name_df = new_name_df[new_order]
final_name_df = new_name_df.rename(columns={'destructionPercentage_1' : 'Attack 1 %', 'destructionPercentage_2' : 'Attack 2 %', 
                                            'stars_1' : 'Attack 1 Stars', 'stars_2' : 'Attack 2 Stars', 'total_attacks' : 'Total Attacks'})
final_name_df
# Out:
#                Total Attacks  Avg %  Attack 1 %  Attack 2 %  Attack 1 Stars  \
# member_name
# Ben Dover                  2  88.00      100.00       76.00            3.00
# Drippy                     1  45.00       45.00         NaN            1.00
# Luke                       2 100.00      100.00      100.00            3.00
# MeekMulli                  1  83.00       83.00         NaN            1.00
# MewThree                   1  47.00       47.00         NaN            1.00
# Shamrock 2.0               2  87.00       77.00       97.00            1.00
# Tony                       2  82.50      100.00       65.00            3.00
# Wreckit Ralph              2 100.00      100.00      100.00            3.00
# mcnasty                    2 100.00      100.00      100.00            3.00
# winston                    2  94.00      100.00       88.00            3.00
#
#                Attack 2 Stars  Total Stars
# member_name
# Ben Dover                1.00         4.00
# Drippy                    NaN         1.00
# Luke                     3.00         6.00
# MeekMulli                 NaN         1.00
# MewThree                  NaN         1.00
# Shamrock 2.0             2.00         3.00
# Tony                     2.00         5.00
# Wreckit Ralph            3.00         6.00
# mcnasty                  3.00         6.00
# winston                  1.00         4.00

# %%
try:
    total_members_df = total_members_df.set_index('name')
except KeyError:
    pass

# %%
combined_df = final_name_df.reindex(total_members_df.index)
combined_df.fillna(0, inplace=True)
combined_df.sort_values(["Total Attacks", 'Total Stars', 'Avg %'], ascending=False, inplace=True)

# %%
def colors(row):
    if row['Total Attacks'] == 2.0:
        color = "rgb(0,255,0)"
    elif row['Total Attacks'] == 1.0:
        color = "yellow"
    else:
        color = "red"
    return [f'color: {color}'] * len(row)

# %%
styled_df = combined_df.style.apply(colors, axis=1).format('{:.1f}')
styled_df
# Out:
# <style type="text/css">
# #T_8495e_row0_col0, #T_8495e_row0_col1, #T_8495e_row0_col2, #T_8495e_row0_col3, #T_8495e_row0_col4, #T_8495e_row0_col5, #T_8495e_row0_col6, #T_8495e_row1_col0, #T_8495e_row1_col1, #T_8495e_row1_col2, #T_8495e_row1_col3, #T_8495e_row1_col4, #T_8495e_row1_col5, #T_8495e_row1_col6, #T_8495e_row2_col0, #T_8495e_row2_col1, #T_8495e_row2_col2, #T_8495e_row2_col3, #T_8495e_row2_col4, #T_8495e_row2_col5, #T_8495e_row2_col6, #T_8495e_row3_col0, #T_8495e_row3_col1, #T_8495e_row3_col2, #T_8495e_row3_col3, #T_8495e_row3_col4, #T_8495e_row3_col5, #T_8495e_row3_col6, #T_8495e_row4_col0, #T_8495e_row4_col1, #T_8495e_row4_col2, #T_8495e_row4_col3, #T_8495e_row4_col4, #T_8495e_row4_col5, #T_8495e_row4_col6, #T_8495e_row5_col0, #T_8495e_row5_col1, #T_8495e_row5_col2, #T_8495e_row5_col3, #T_8495e_row5_col4, #T_8495e_row5_col5, #T_8495e_row5_col6, #T_8495e_row6_col0, #T_8495e_row6_col1, #T_8495e_row6_col2, #T_8495e_row6_col3, #T_8495e_row6_col4, #T_8495e_row6_col5, #T_8495e_row6_col6 {
#   color: rgb(0,255,0);
# }
# #T_8495e_row7_col0, #T_8495e_row7_col1, #T_8495e_row7_col2, #T_8495e_row7_col3, #T_8495e_row7_col4, #T_8495e_row7_col5, #T_8495e_row7_col6, #T_8495e_row8_col0, #T_8495e_row8_col1, #T_8495e_row8_col2, #T_8495e_row8_col3, #T_8495e_row8_col4, #T_8495e_row8_col5, #T_8495e_row8_col6, #T_8495e_row9_col0, #T_8495e_row9_col1, #T_8495e_row9_col2, #T_8495e_row9_col3, #T_8495e_row9_col4, #T_8495e_row9_col5, #T_8495e_row9_col6 {
#   color: yellow;
# }
# #T_8495e_row10_col0, #T_8495e_row10_col1, #T_8495e_row10_col2, #T_8495e_row10_col3, #T_8495e_row10_col4, #T_8495e_row10_col5, #T_8495e_row10_col6, #T_8495e_row11_col0, #T_8495e_row11_col1, #T_8495e_row11_col2, #T_8495e_row11_col3, #T_8495e_row11_col4, #T_8495e_row11_col5, #T_8495e_row11_col6, #T_8495e_row12_col0, #T_8495e_row12_col1, #T_8495e_row12_col2, #T_8495e_row12_col3, #T_8495e_row12_col4, #T_8495e_row12_col5, #T_8495e_row12_col6, #T_8495e_row13_col0, #T_8495e_row13_col1, #T_8495e_row13_col2, #T_8495e_row13_col3, #T_8495e_row13_col4, #T_8495e_row13_col5, #T_8495e_row13_col6, #T_8495e_row14_col0, #T_8495e_row14_col1, #T_8495e_row14_col2, #T_8495e_row14_col3, #T_8495e_row14_col4, #T_8495e_row14_col5, #T_8495e_row14_col6 {
#   color: red;
# }
# </style>
# <table id="T_8495e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8495e_level0_col0" class="col_heading level0 col0" >Total Attacks</th>
#       <th id="T_8495e_level0_col1" class="col_heading level0 col1" >Avg %</th>
#       <th id="T_8495e_level0_col2" class="col_heading level0 col2" >Attack 1 %</th>
#       <th id="T_8495e_level0_col3" class="col_heading level0 col3" >Attack 2 %</th>
#       <th id="T_8495e_level0_col4" class="col_heading level0 col4" >Attack 1 Stars</th>
#       <th id="T_8495e_level0_col5" class="col_heading level0 col5" >Attack 2 Stars</th>
#       <th id="T_8495e_level0_col6" class="col_heading level0 col6" >Total Stars</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8495e_level0_row0" class="row_heading level0 row0" >mcnasty</th>
#       <td id="T_8495e_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_8495e_row0_col1" class="data row0 col1" >100.0</td>
#       <td id="T_8495e_row0_col2" class="data row0 col2" >100.0</td>
#       <td id="T_8495e_row0_col3" class="data row0 col3" >100.0</td>
#       <td id="T_8495e_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_8495e_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_8495e_row0_col6" class="data row0 col6" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row1" class="row_heading level0 row1" >Luke</th>
#       <td id="T_8495e_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_8495e_row1_col1" class="data row1 col1" >100.0</td>
#       <td id="T_8495e_row1_col2" class="data row1 col2" >100.0</td>
#       <td id="T_8495e_row1_col3" class="data row1 col3" >100.0</td>
#       <td id="T_8495e_row1_col4" class="data row1 col4" >3.0</td>
#       <td id="T_8495e_row1_col5" class="data row1 col5" >3.0</td>
#       <td id="T_8495e_row1_col6" class="data row1 col6" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row2" class="row_heading level0 row2" >Wreckit Ralph</th>
#       <td id="T_8495e_row2_col0" class="data row2 col0" >2.0</td>
#       <td id="T_8495e_row2_col1" class="data row2 col1" >100.0</td>
#       <td id="T_8495e_row2_col2" class="data row2 col2" >100.0</td>
#       <td id="T_8495e_row2_col3" class="data row2 col3" >100.0</td>
#       <td id="T_8495e_row2_col4" class="data row2 col4" >3.0</td>
#       <td id="T_8495e_row2_col5" class="data row2 col5" >3.0</td>
#       <td id="T_8495e_row2_col6" class="data row2 col6" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row3" class="row_heading level0 row3" >Tony</th>
#       <td id="T_8495e_row3_col0" class="data row3 col0" >2.0</td>
#       <td id="T_8495e_row3_col1" class="data row3 col1" >82.5</td>
#       <td id="T_8495e_row3_col2" class="data row3 col2" >100.0</td>
#       <td id="T_8495e_row3_col3" class="data row3 col3" >65.0</td>
#       <td id="T_8495e_row3_col4" class="data row3 col4" >3.0</td>
#       <td id="T_8495e_row3_col5" class="data row3 col5" >2.0</td>
#       <td id="T_8495e_row3_col6" class="data row3 col6" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row4" class="row_heading level0 row4" >winston</th>
#       <td id="T_8495e_row4_col0" class="data row4 col0" >2.0</td>
#       <td id="T_8495e_row4_col1" class="data row4 col1" >94.0</td>
#       <td id="T_8495e_row4_col2" class="data row4 col2" >100.0</td>
#       <td id="T_8495e_row4_col3" class="data row4 col3" >88.0</td>
#       <td id="T_8495e_row4_col4" class="data row4 col4" >3.0</td>
#       <td id="T_8495e_row4_col5" class="data row4 col5" >1.0</td>
#       <td id="T_8495e_row4_col6" class="data row4 col6" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row5" class="row_heading level0 row5" >Ben Dover</th>
#       <td id="T_8495e_row5_col0" class="data row5 col0" >2.0</td>
#       <td id="T_8495e_row5_col1" class="data row5 col1" >88.0</td>
#       <td id="T_8495e_row5_col2" class="data row5 col2" >100.0</td>
#       <td id="T_8495e_row5_col3" class="data row5 col3" >76.0</td>
#       <td id="T_8495e_row5_col4" class="data row5 col4" >3.0</td>
#       <td id="T_8495e_row5_col5" class="data row5 col5" >1.0</td>
#       <td id="T_8495e_row5_col6" class="data row5 col6" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row6" class="row_heading level0 row6" >Shamrock 2.0</th>
#       <td id="T_8495e_row6_col0" class="data row6 col0" >2.0</td>
#       <td id="T_8495e_row6_col1" class="data row6 col1" >87.0</td>
#       <td id="T_8495e_row6_col2" class="data row6 col2" >77.0</td>
#       <td id="T_8495e_row6_col3" class="data row6 col3" >97.0</td>
#       <td id="T_8495e_row6_col4" class="data row6 col4" >1.0</td>
#       <td id="T_8495e_row6_col5" class="data row6 col5" >2.0</td>
#       <td id="T_8495e_row6_col6" class="data row6 col6" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row7" class="row_heading level0 row7" >MeekMulli</th>
#       <td id="T_8495e_row7_col0" class="data row7 col0" >1.0</td>
#       <td id="T_8495e_row7_col1" class="data row7 col1" >83.0</td>
#       <td id="T_8495e_row7_col2" class="data row7 col2" >83.0</td>
#       <td id="T_8495e_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_8495e_row7_col4" class="data row7 col4" >1.0</td>
#       <td id="T_8495e_row7_col5" class="data row7 col5" >0.0</td>
#       <td id="T_8495e_row7_col6" class="data row7 col6" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_8495e_level0_row8" class="row_heading level0 row8" >MewThree</th>
#       <td id="T_8495e_row8_col0" class="data row8 col0" >1.0</td>
